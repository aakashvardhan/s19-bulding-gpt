# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
local_dir = 's19-bulding-gpt'
repo_url = 'https://github.com/aakashvardhan/s19-bulding-gpt.git'

# Check if the local directory already exists
if not os.path.exists(local_dir):
    # Clone the repository because it does not exist
    # !git clone --quiet {repo_url}
else:
    # Change directory to the local repository
    # %cd {local_dir}
    # Pull the latest changes because the repository already exists
    # !git pull
# Out:
# /content/s19-bulding-gpt
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 1), reused 4 (delta 1), pack-reused 0
# Unpacking objects: 100% (4/4), 1.16 KiB | 1.16 MiB/s, done.
# From https://github.com/aakashvardhan/s19-bulding-gpt
#    8abbcfb..8500b3d  main       -> origin/main
# Updating 8abbcfb..8500b3d
# Fast-forward
#  train-v2.ipynb | 1 +
#  v2.py          | 2 +-
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 train-v2.ipynb

# %%
# !python /content/s19-bulding-gpt/v2.py
# Out:
# Iteration(step) 0: Train loss: 4.6158, Val loss: 4.6150
# Iteration(step) 500: Train loss: 2.1058, Val loss: 2.1544
# Iteration(step) 1000: Train loss: 1.6555, Val loss: 1.8149
# Iteration(step) 1500: Train loss: 1.4815, Val loss: 1.6717
# Iteration(step) 2000: Train loss: 1.3783, Val loss: 1.5912
# Iteration(step) 2500: Train loss: 1.3039, Val loss: 1.5559
# Iteration(step) 3000: Train loss: 1.2522, Val loss: 1.5245
# Iteration(step) 3500: Train loss: 1.2029, Val loss: 1.5008
# Iteration(step) 4000: Train loss: 1.1625, Val loss: 1.4916
# Iteration(step) 4500: Train loss: 1.1234, Val loss: 1.4890
#
# is none.
#
# Clown:
# My lady Marcius is even is brother.
#
# BENVOLIO:
# That can we have struck in an unproper pity.
#
# BENVOLIO:
# Nay, it summer it.
#
# ESCALUS:
# Were he he offend.
#
# DUKE VINCENTIO:
# These that's not.
#
# WARWICK:
# Ansidece way, as you care, let's a head; that e's eas?
#
# ESCALUS:
# My love and all their are legs from her
# ...
